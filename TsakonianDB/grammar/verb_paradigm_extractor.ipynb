# %% [markdown]
# # Tsakonian verb paradigm extractor

# %% [markdown]
# # Preparation

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Raw data

# %%
df = pd.read_excel('../tables/verbs.xlsx').fillna('')
df.head()
# Out:
#    tsakonian                       greek ypot_enest ypot_aor orist_aor  \
# 0    αβαίνου                     λαβαίνω                         αβήκα
# 1  αβζ̌ύντου  υποφέρω από δίψα, ουρλιάζω                         αβζύα
# 2   αβούκ̇ου                      λαβώνω                        αβούκα
# 3    αγανίου            παθαίνω οξείδωση                        αγανία
# 4    αγκατού                      φράσσω                       αγατήκα
#
#   metochi  source
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %% [markdown]
# # A paradigms

# %% [markdown]
# Verbs ending in `-ου`

# %%
# A1
ending = 'νου'
negative_ending = 'ούνου'

paradigm = 'Α1'
add = True
mask = (df['tsakonian'].str.endswith(ending) & ~df['tsakonian'].str.endswith(negative_ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#       tsakonian                greek ypot_enest ypot_aor   orist_aor  \
# 0       αβαίνου              λαβαίνω                           αβήκα
# 5     αγκραίνου            μπλέκομαι                         αγκράκα
# 26        βάνου                 βάζω
# 41       δεΐνου                 δένω                          εδεήκα
# 43      δεχάνου               δείχνω                           εδενά
# 61   καταβαίνου          καταλαβαίνω
# 63     κατσίνου              δαγκώνω                        εκατσίκα
# 66       κιάνου                πιάνω              κιάσου      εκιάκα
# 70        κίνου                 πίνω      κίνου     κίου      εγκίκα
# 72      κλείνου               κλείνω              κλείου     εκλείκα
# 79    μιτσαίνου             μικραίνω                      εμιτσ̌άγκα
# 81      μπαίνου               μπαίνω    μπαίνου    μπάου      εμπάκα
# 82      μπαΐνου     ανεβαίνω; Βγαίνω    μπαΐνου   μπαΐου     εμπαήκα
# 83       μπάνου                βγάζω     μπάνου   μπάλου   επμαλ̣ήκα
# 99     ξεχαίνου               ξεχνάω                         εξεχάκα
# 126     τ̇αίνου            σηκώνομαι    τ̇αίνου    τ̇άου      ετ̇ακα
# 130    τσαφήνου    αφήνω, ελευθερώνω             τσαφήου    ετσαφήκα
# 139     φταίνου                 ψήνω               φτάου      εφτάκα
# 145       χάνου                 χάνω      χάνου     χάου       εχάκα
# 147      ψαίνου  σφουγγίζω, σκουπίζω                           εψάκα
#
#       metochi  source paradigm
# 0                   1       Α1
# 5                   1       Α1
# 26                  1       Α1
# 41                  1       Α1
# 43                  1       Α1
# 61                  1       Α1
# 63                  1       Α1
# 66     κιατ̇έ       1       Α1
# 70      γκιτέ       1       Α1
# 72     κλιστέ       1       Α1
# 79                  1       Α1
# 81      μπατέ       1       Α1
# 82     μπαητέ       1       Α1
# 83   μπαλ̣ητέ       1       Α1
# 99                  1       Α1
# 126     τ̇ατέ       1       Α1
# 130                 1       Α1
# 139     φτατέ       1       Α1
# 145      χατέ       1       Α1
# 147                 1       Α1

# %%
# A2
ending = 'ούνου'
paradigm = 'Α2'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#       tsakonian        greek ypot_enest ypot_aor   orist_aor    metochi  \
# 64   κατσ̌ούνου        σπάζω             κατσ̌ού  εκατσ̌ούκα  κατσ̌ουτέ
# 112   ποτσούνου      φορτώνω                       εποτσούκα
# 122      σούνου  φτάνω, σώζω              σούσου      εσούκα     σουστέ
#
#      source paradigm
# 64        1       Α2
# 112       1       Α2
# 122       1       Α2

# %%
# A3
ending = 'ούκ̇ου'
paradigm = 'Α3'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#        tsakonian              greek ypot_enest ypot_aor   orist_aor  \
# 2       αβούκ̇ου             λαβώνω                          αβούκα
# 13    ανεμούκ̇ου              πετάω                        ανεμούκα
# 19    αποσούκ̇ου  πηγαίνω, μεταφέρω              αποσού    αποσούκα
# 20     απρούκ̇ου             απλώνω               απρού     απρούκα
# 34     γκιούκ̇ου              ντύνω               γκιου    εγκιούκα
# 74   κ̇οντούκ̇ου             κρατάω             κ̇οντού  εκ̇οντούκα
# 77     μακούκ̇ου           μαλακώνω                        εμακούκα
# 100     ξηούκ̇ου             ξηλώνω                         εξηούκα
# 101    οργούκ̇ου             οργώνω               οργού     οργούκα
# 120  σκαρμούκ̇ου  ξαφνιάζω, τρομάζω                      εσκαρμούκα
# 144   χαμεούκ̇ου           χαμηλώνω                       εχαμεούκα
#
#        metochi  source paradigm
# 2                    1       Α3
# 13                   1       Α3
# 19    αποσουτέ       1       Α3
# 20     απρουτέ       1       Α3
# 34     γκιουτέ       1       Α3
# 74   κ̇οντουτέ       1       Α3
# 77                   1       Α3
# 100                  1       Α3
# 101    οργουτέ       1       Α3
# 120                  1       Α3
# 144                  1       Α3

# %%
# A4
ending = ('ίχου', 'ίντου', 'ύντου', 'άντου')
paradigm = 'Α4`'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#        tsakonian                       greek ypot_enest   ypot_aor  orist_aor  \
# 1      αβζ̌ύντου  υποφέρω από δίψα, ουρλιάζω                            αβζύα
# 9         ακίχου                     αλατίζω                             ακία
# 10   ακ̇ουγγίχου                     ακουμπώ                        ακ̇ουγγία
# 14      ανοίντου                      ανοίγω                            ανοία
# 46     δρανίντου               τρέχω γρήγορα                          εδρανία
# 54       θυνίχου                      θυμίζω              θυνίτσου     εθυνία
# 73     κ̇ολλίχου                       κολλώ                         εκ̇ολλία
# 94    ντιζικίχου             πειράζω, ενοχλώ
# 98       ξερίχου                ρίχνω, πετάω                           εξερία
# 128    τραβίντου                      τραβάω  τραβίντου  τραβίτσου    ετραβία
# 132   τσιταίντου                       πέφτω                           ετσιτά
# 152    φωνιάντου                      φωνάζω  φωνιάντου  φωνιάτσου     εφωνιά
#
#       metochi  source paradigm
# 1                   1      Α4`
# 9                   1      Α4`
# 10                  1      Α4`
# 14                  1      Α4`
# 46                  1      Α4`
# 54    θυνιτ̇έ       1      Α4`
# 73                  1      Α4`
# 94                  1      Α4`
# 98                  1      Α4`
# 128                 1      Α4`
# 132                 1      Α4`
# 152  φωνιατ̇έ       1      Α4`

# %%
# A5
ending = 'ζου'
paradigm = 'Α5'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#        tsakonian                              greek ypot_enest   ypot_aor  \
# 7      ακεικάζου             συμπεραίνω, παρομοιάζω
# 11   αλικογκίζου                εμποδίζω, καθυστερώ
# 15      αντζάζου  ακουμοώ την πληγή και την ερεθίζω
# 17     απογιάζου           ξεγελώ την πείνα με κάτι
# 29    βουκ̇ιάζου                     βουτάω, αρπάζω
# 58     καρδιάζου                             κρυώνω
# 76       κ̇ρύζου                              πλύνω               κ̇ρύσου
# 91     νιουρίζου                            γνωρίζω  νιουρίζου  νιουρίσου
# 97       ξεκάζου                            κοιτάζω
# 149     ψαχνίζου                           στεγνώνω
#
#      orist_aor    metochi  source paradigm
# 7       ακεικά                  1       Α5
# 11   αλικογκία                  1       Α5
# 15       αντζά                  1       Α5
# 17      απογιά                  1       Α5
# 29    εβουκ̇ιά                  1       Α5
# 58     εκαρδιά                  1       Α5
# 76      εκ̇ρύα                  1       Α5
# 91    ενιουρία  νιουριστέ       1       Α5
# 97                              1       Α5
# 149    εψαχνία                  1       Α5

# %%
# A6
ending = 'φου'
paradigm = 'Α6'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#      tsakonian             greek ypot_enest   ypot_aor  orist_aor    metochi  \
# 36   γκριούφου             κρύβω             γκριούψου  εγκριούβα  γκριουφτέ
# 38      γράφου             γράφω     γράφου      γράψω     εγράβα     γραφτέ
# 71     κιούφου          κοιμάμαι    κιούφου    κιούψου    εκιούβα    κιουφτέ
# 93       νίφου  πλένω το πρόσωπο                            ενίβα
# 96       ξάφου     χτυπώ ξαφνικά                            εξάβα
# 107      πάφου     παύω,σταματάω                            επαύα
# 133    τσ̌ίφου             τρίβω                          ετσ̌ίβα
#
#      source paradigm
# 36        1       Α6
# 38        1       Α6
# 71        1       Α6
# 93        1       Α6
# 96        1       Α6
# 107       1       Α6
# 133       1       Α6

# %%
# A7
ending = 'έγγου'
paradigm = 'Α7'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#          tsakonian                          greek    ypot_enest      ypot_aor  \
# 31        γαλέγγου  ρίχνω τον καρπό πριν ωριμάσει
# 45       δουλέγγου                        δουλεύω                     δουλέψω
# 47           έγγου                        πηγαίνω         έγγου          ζάου
# 85        μπλέγγου                         διώχνω      μπλέγγου       μπλέψου
# 86        μπλέγγου               μπερδεύω, μπλέκω      μπλέγγου       μπλέξου
# 118       σαλέγγου                       κινούμαι
# 124  στενοχωρέγγου                      στενοχωρώ  στενοχωρέγγω  στενοχωρέψου
#
#         orist_aor   metochi  source paradigm
# 31        εγαλεύα                 1       Α7
# 45       εδουλεύα  δουλευτέ       2       Α7
# 47          εζάκα      ζατέ       1       Α7
# 85        εμπλεύα   μπλευτέ       1       Α7
# 86         εμπλέα   μπλεχτέ       1       Α7
# 118       εσαλεύα                 1       Α7
# 124  εστενοχωρεύα                 1       Α7

# %%
# A8
ending = 'ίγγου'
paradigm = 'Α8'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#     tsakonian  greek ypot_enest ypot_aor orist_aor metochi  source paradigm
# 115   πρίγγου  πνίγω             πρίτσου     επρία               1       Α8

# %%
# A9
ending = 'έχου'
paradigm = 'Α9'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#       tsakonian     greek ypot_enest    ypot_aor  orist_aor metochi  source  \
# 30       βρέχου     βρέχω     βρέχου     βρέτσου      εβρέα  βρετ̇έ       1
# 49       ερέχου    βρίσκω                  ρέσου      ερέκα  ερεστέ       1
# 51         έχου       έχω       έχου        έχου                          1
# 84       μπέχου   σκεπάζω     μπέχου     μπέτσου      εμπέα   μπετέ       1
# 104    παντέχου  περιμένω                                                 1
# 114  π̇ουντέχου     σβήνω             πουντέτσου  επ̇ουντέα               1
#
#     paradigm
# 30        Α9
# 49        Α9
# 51        Α9
# 84        Α9
# 104       Α9
# 114       Α9

# %%
# A10
ending = 'ίου'
paradigm = 'Α10'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#     tsakonian             greek ypot_enest  ypot_aor orist_aor metochi  \
# 3     αγανίου  παθαίνω οξείδωση                         αγανία
# 6    ακαλ̣ίου              κυλώ  ακαλ̣ήνου  ακαλ̣ίου  ακαλ̣ίκα
# 44       δίου              δίνω      δίνου       δου    εδούκα   δουτέ
# 60     κασίου          κοιμάμαι
# 62    κ̇ατίου          τοποθετώ                       εκ̇ατίκα
# 90       νίου             ακούω      νίνου     νιάου    ενιάκα   νιατέ
# 95      ντίου             χτυπώ     ντίνου      ντου   εντούκα  ντουτέ
# 106    παρίου           έρχομαι     παρίμα     μόλου     εκάνα   φερτέ
# 110     ποίου              κάνω     ποίνου     ποίου    εμπήκα  μποιτέ
# 119   σαπρίου            σαπίζω                        εσαπρία
# 141    φταίου             φταίω                        εφταίκα
#
#      source paradigm
# 3         1      Α10
# 6         1      Α10
# 44        1      Α10
# 60        1      Α10
# 62        1      Α10
# 90        1      Α10
# 95        1      Α10
# 106       1      Α10
# 110       1      Α10
# 119       1      Α10
# 141       1      Α10

# %%
# A11
ending = 'αίσου'
paradigm = 'Α11'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#    tsakonian greek ypot_enest ypot_aor orist_aor metochi  source paradigm
# 40    δαίσου  καίω     δαίσου     δάου     εδάκα               1      Α11

# %%
# A12
ending = 'ρίκ̇ου'
paradigm = 'Α12'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#        tsakonian      greek ypot_enest ypot_aor   orist_aor metochi  source  \
# 22       αρίκ̇ου     παίρνω                άρου        άγκα   παρτέ       1
# 57  καραφερίκ̇ου  καταφέρνω                      εκατανέγκα               1
#
#    paradigm
# 22      Α12
# 57      Α12

# %%
# A13
ending = 'ρου'
paradigm = 'Α13'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#    tsakonian         greek ypot_enest ypot_aor orist_aor metochi  source  \
# 32    γείρου     επιστρέφω                       εγείρκα               1
# 42     δέρου  δέρνω, χτυπώ                        εδάρκα               1
#
#    paradigm
# 32      Α13
# 42      Α13

# %%
# A14
ending = 'άσσου'
paradigm = 'Α14'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#     tsakonian    greek ypot_enest ypot_aor orist_aor metochi  source paradigm
# 25      άσσου   αλλάζω                          α/εά               1      Α14
# 111  ποτάσσου  φτουράω                         εποτά               1      Α14
# 151   αράσσου   αράσσω    αράσσου  αράτσου       αρά               2      Α14

# %% [markdown]
# # Β paradigms

# %% [markdown]
# Verbs ending in `-ού`

# %%
# Β1
ending = 'ού'
aoristos_ending = 'άκα'
paradigm = 'Β1'

add = True
mask = (df['tsakonian'].str.endswith(ending) & 
        df['orist_aor'].str.endswith(aoristos_ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#     tsakonian          greek ypot_enest ypot_aor orist_aor   metochi  source  \
# 21     αραμού  μένω, κατοικώ             αραμάου   αραμάκα   αραματέ       1
# 28        βού          κλαίω     βούνου   βάτσου     εβάκα                 1
# 33       γεού          γελάω   γελ̣ήνου    γιάου    εγιάκα                 1
# 68      κιμού           τιμώ                       εκιμάκα                 1
# 80      μοζού          πονάω    μοζήνου   μοζάου   εμοζάκα  μοζαΐχου       1
# 102      ορού          βλέπω     ορήνου    οράου     οράκα     ορατέ       1
# 109     περού          περνώ    περήνου   περάου   επεράκα    περατέ       1
# 138    φουσού          φυσάω   φουσήνου  φουσάου  εφουσάκα                 1
# 146      χαού          χαλάω   χαλ̣ήνου     χάου     εχάκα      χαρέ       1
#
#     paradigm
# 21        Β1
# 28        Β1
# 33        Β1
# 68        Β1
# 80        Β1
# 102       Β1
# 109       Β1
# 138       Β1
# 146       Β1

# %%
# Β2
ending = 'ού'
aoristos_ending = 'ήκα'
paradigm = 'Β2'

add = True
mask = (df['tsakonian'].str.endswith(ending) & 
        df['orist_aor'].str.endswith(aoristos_ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#     tsakonian       greek ypot_enest ypot_aor    orist_aor  metochi  source  \
# 4     αγκατού      φράσσω                          αγατήκα                1
# 12     αμογού     ομολογώ                          αμογήκα                1
# 23       αρού      αρμέγω     αρήνου    αρήου        αρήκα    αρητέ       1
# 24       ασού     σουρώνω                            ασήκα                1
# 27      βογού      ευλογώ                           βογήκα                1
# 52    ζυρογού  βρωμοκοπάω                        εζυρογήκα                1
# 75    κουβαού     κουβαλώ                      εκουβαλ̣ήκα                1
# 78    μετσ̌ού       μετρώ                        εμετσ̌ήκα                1
# 89       νιού       μηλάω   νιλ̣ήνου  νιλ̣ήου     ενιλ̣ήκα  νιλ̣ητέ       1
# 117     ρωτού       ρωτάω    ρωτήνου   ρωτήου      ερωτήκα   ρωτητέ       1
# 135   τσ̌υγού       τρυγώ                       εστσ̌υγήκα                1
# 148     ψαφού       ψάχνω    ψαφήνου   ψαφήου      εψαφήκα   ψαφητέ       1
# 150     νικού        νικώ             νιτζήου     ενιτζήκα                2
#
#     paradigm
# 4         Β2
# 12        Β2
# 23        Β2
# 24        Β2
# 27        Β2
# 52        Β2
# 75        Β2
# 78        Β2
# 89        Β2
# 117       Β2
# 135       Β2
# 148       Β2
# 150       Β2

# %%
# Β3
ending = 'ού'
aoristos_ending = 'έκα'
paradigm = 'Β3'

add = True
mask = (df['tsakonian'].str.endswith(ending) & 
        df['orist_aor'].str.endswith(aoristos_ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#       tsakonian                     greek ypot_enest ypot_aor     orist_aor  \
# 16          αού                       λέω     αλήνου    αλήου         επέκα
# 69      κιμωρού                    τιμωρώ                         εκιμωρέκα
# 87       μπορού                     μπορώ             μπορέου      εμπορέκα
# 105  παραθαρρού  χαλαρώνω την προσοχή μου                      επαραθαρρέκα
# 137       φορού                     φοράω    φορήνου   φορέου       εφορέκα
#
#      metochi  source paradigm
# 16      πετέ       1       Β3
# 69                 1       Β3
# 87                 1       Β3
# 105                1       Β3
# 137  φορεστέ       1       Β3

# %% [markdown]
# # Γ paradigms: passive voices

# %%
# Γ
ending = 'ε'
paradigm = 'Γ'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#              tsakonian          greek       ypot_enest       ypot_aor  \
# 8       ακισταινούμενε     κουράζομαι
# 35       γκιουκ̇ούμενε       ντύνομαι                        γκιουθού
# 37       γκριουφούμενε     γκριουφτού                      γκριουφτού
# 39          γραφούμενε       γράφομαι         γραφούμα        γραφτού
# 50         ερικ̇ούμενε      βρίσκομαι                          ρεστού
# 53           θυμούμενε        θυμάμαι                         θυνηθού
# 59            κασημένε        κάθομαι           κασήμα        κατσάου
# 67          κιανούμενε       πιάνομαι                         κιατ̇ού
# 92      νιουρισκούμενε     γνωρίζομαι     νιουρισκούμα     νιουριστού
# 103           ορούμενε       φαίνομαι         ορινούμα         οραθού
# 116       ρωτηκ̇ούμενε       ρωτιέμαι       ρωτηκ̇ούμα        ρωτηθού
# 123        σουσκούμενε       τελειώνω                         σουστού
# 125  στενοχωρεγγούμενε  στεναχωριέμαι  στενοχωρεγγούμα  στενοχωρευτού
# 129      τραβιντούμενε      τραβιέμαι      τραβιντούμα      τραβιτ̇ού
# 140        φταινούμενε        ψήνομαι                          φταθού
# 143      φωνιαντούμενε      φωνάζομαι      φωνιαντούμα      φωνιατ̇ού
#
#         orist_aor    metochi  source paradigm
# 8        ακιστάμα                  1        Γ
# 35       εγκιούμα    γκιουτέ       1        Γ
# 37      εγκριούμα  γκριουφτέ       1        Γ
# 39        εγράμμα     γραφτέ       1        Γ
# 50         ερέσια                  1        Γ
# 53        εθυνήμα                  1        Γ
# 59       εκατσάκα    κατσατέ       1        Γ
# 67         εκιάμα     κιατ̇έ       1        Γ
# 92     ενιουρίσμα  νιουριστέ       1        Γ
# 103         οράμα      ορατέ       1        Γ
# 116       ερωτήμα     ρωτητέ       1        Γ
# 123       εσούσμα     σουστέ       1        Γ
# 125  εστενοχωρέμα                  1        Γ
# 129      ετραβίμα   τραβιτ̇έ       1        Γ
# 140        εφτάμα      φτατέ       1        Γ
# 143      εφωνιάμα   φωνιατ̇έ       1        Γ

# %% [markdown]
# # Unorganized verbs

# %%
# Extract verbs where the paradigm is empty
df[df['paradigm'].isnull()]
# Out:
#       tsakonian             greek ypot_enest    ypot_aor  orist_aor  metochi  \
# 18        αποού            στέλνω                          απολ̣ύκα
# 48          ένι             είμαι        ένι         ένι        έμα
# 55   κ̇ακ̇ούχου       χώνω, έχωσα                         εκ̇ακ̇ούα
# 56        κάμου  καματεύω, σπέρνω                 καμέου    εκαμεκα
# 65       κεινού            πεινάω                κεινάου   εκείνακα  κεινατέ
# 88        νέμου             βοσκώ      νέμου      νεμάου    ενεμάκα   νεματέ
# 108    πενάκ̇ου           πεθαίνω                πεθάνου    επενάκα   πενατέ
# 113         που            πουλάω  πουλ̣ήνου    πουλ̣ήου  επουλ̣ήκα
# 121      σκωρού           συγχωρώ                         εσκουγκία
# 127     τ̇αΐχου            σηκώνω    τ̇αΐχου     τ̇αΐσου     ετ̇αΐα  τ̇αΐστέ
# 131     τσ̌άχου             τρέχω    τσ̌αχου  τσ̌αχίτσου  ετσ̌αχήκα
# 134       τσ̌ου              τρώω   τσ̌ούνου        φάου     εφαήκα    φαητέ
# 136    φοζαΐχου            φοβίζω                           εφοζαΐα
# 142        φύου             φεύγω      φύνου      φύτσου     εφύγκα
#
#      source paradigm
# 18        1      NaN
# 48        1      NaN
# 55        1      NaN
# 56        1      NaN
# 65        1      NaN
# 88        1      NaN
# 108       1      NaN
# 113       1      NaN
# 121       1      NaN
# 127       1      NaN
# 131       1      NaN
# 134       1      NaN
# 136       1      NaN
# 142       1      NaN
