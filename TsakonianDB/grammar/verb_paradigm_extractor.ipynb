# %% [markdown]
# # Tsakonian verb paradigm extractor

# %% [markdown]
# # Preparation

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Raw data

# %%
df = pd.read_excel('../tables/verbs.xlsx').fillna('')
df.head()
# Out:
#       tsakonian                       greek  ypot_enest orist_aor ypot_aor  \
# 0       αβαίνου                     λαβαίνω     αβαίνου     αβήκα     άβου
# 1     αβζ̌ύντου  υποφέρω από δίψα, ουρλιάζω                 αβζύα
# 2      αβούκ̇ου                      λαβώνω    αβούκ̇ου    αβούκα     αβού
# 3  αβουκ̇ούμενε                   λαβώνομαι  αβουκ̇ούμα    αβούμα  αβουθού
# 4       αγανίου            παθαίνω οξείδωση                αγανία
#
#   metochi prost_aor source passive passive_greek pas_ypot_enest pas_orist_aor  \
# 0               άβε      1
# 1                        1
# 2  αβουτέ      άβου      1
# 3            αβουτέ      2
# 4                        1
#
#   pas_ypot_aor Columna1
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # A paradigms

# %% [markdown]
# Verbs ending in `-ου`

# %%
# A1
ending = 'νου'
negative_ending = 'ούνου'

paradigm = 'Α1'
add = True
mask = (df['tsakonian'].str.endswith(ending) & ~df['tsakonian'].str.endswith(negative_ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#        tsakonian                          greek   ypot_enest    orist_aor  \
# 0        αβαίνου                        λαβαίνω      αβαίνου        αβήκα
# 6      αγκραίνου                      μπλέκομαι                   αγκράκα
# 25      αποβάνου                       αποβάλλω     αποβάνου  απολβαλ̣ήκα
# 34     αποψαίνου  αποψάω, αποσπογγίζω, καθαρίζω    αποψαίνου      αποψάκα
# 47   ατσ̌εραίνου                       μεγαλωνώ  ατσ̌εραίνου   ατσ̌ερέγκα
# 50        αφίνου                          αφίνω       αφίνου        αφήκα
# 54      βαθαίνου                         βαθύνω            -     εβαθέγκα
# 55         βάνου                           βάζω            -     εβαλ̣ήκα
# 68        δεΐνου                           δένω                    εδεήκα
# 70       δεχάνου                         δείχνω                     εδενά
# 88    καταβαίνου                    καταλαβαίνω
# 90      κατσίνου                        δαγκώνω                  εκατσίκα
# 93        κιάνου                          πιάνω                    εκιάκα
# 96         κίνου                           πίνω        κίνου       εγκίκα
# 98       κλείνου                         κλείνω                   εκλείκα
# 105    μιτσαίνου                       μικραίνω                εμιτσ̌άγκα
# 107      μπαίνου                         μπαίνω      μπαίνου       εμπάκα
# 108      μπαΐνου               ανεβαίνω; Βγαίνω      μπαΐνου      εμπαήκα
# 110       μπάνου                          βγάζω       μπάνου    επμαλ̣ήκα
# 126     ξεχαίνου                         ξεχνάω                   εξεχάκα
# 150      τ̇αίνου                      σηκώνομαι      τ̇αίνου       ετ̇ακα
# 153     τσαφήνου              αφήνω, ελευθερώνω                  ετσαφήκα
# 162      φταίνου                           ψήνω                    εφτάκα
# 169        χάνου                           χάνω        χάνου        εχάκα
# 171       ψαίνου            σφουγγίζω, σκουπίζω                     εψάκα
#
#       ypot_aor   metochi prost_aor source      passive passive_greek  \
# 0         άβου                 άβε      1
# 6                                       1
# 25    αποβάλου                          2
# 34     αποψάου   αποψατέ                2
# 47   ατσ̌ερέου                          2
# 50       αφήου     αφητέ       άφη      2
# 54     βαθένου                          2
# 55       βάλου   βαλ̣ητέ      βάλε      2
# 68                                      1
# 70                                      1
# 88                                      1
# 90                                      1
# 93      κιάσου    κιατ̇έ                1   κιανούμενε      πιάνομαι
# 96        κίου     γκιτέ                1
# 98      κλείου    κλιστέ                1
# 105                                     1
# 107      μπάου     μπατέ                1
# 108     μπαΐου    μπαητέ      μπάη      1
# 110     μπάλου  μπαλ̣ητέ     μπάλε      1
# 126     ξεχάου                          1
# 150      τ̇άου     τ̇ατέ                1
# 153    τσαφήου                          1
# 162      φτάου     φτατέ                1  φταινούμενε       ψήνομαι
# 169       χάου      χατέ                1
# 171                                     1
#
#     pas_ypot_enest pas_orist_aor pas_ypot_aor Columna1 paradigm
# 0                                                            Α1
# 6                                                            Α1
# 25                                                           Α1
# 34                                                           Α1
# 47                                                           Α1
# 50                                                           Α1
# 54                                                           Α1
# 55                                                           Α1
# 68                                                           Α1
# 70                                                           Α1
# 88                                                           Α1
# 90                                                           Α1
# 93                        εκιάμα      κιατ̇ού   κιατ̇έ       Α1
# 96                                                           Α1
# 98                                                           Α1
# 105                                                          Α1
# 107                                                          Α1
# 108                                                          Α1
# 110                                                          Α1
# 126                                                          Α1
# 150                                                          Α1
# 153                                                          Α1
# 162                       εφτάμα       φταθού    φτατέ       Α1
# 169                                                          Α1
# 171                                                          Α1

# %%
# A2
ending = 'ούνου'
paradigm = 'Α2'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#       tsakonian            greek  ypot_enest   orist_aor ypot_aor     metochi  \
# 30   αποτσούνου  αποξέω, αποξύνω  αποτσούνου   αποτσούκα  αποτσού  αποστσουτέ
# 91   κατσ̌ούνου            σπάζω              εκατσ̌ούκα  κατσ̌ού   κατσ̌ουτέ
# 138   ποτσούνου          φορτώνω   ποτσούνου   εποτσούκα   πότσου    ποτσουτέ
# 147      σούνου      φτάνω, σώζω                  εσούκα   σούσου      σουστέ
#
#     prost_aor source         passive passive_greek pas_ypot_enest  \
# 30                 2  αποτσουνούμενε    αποξύνομαι   αποτσουνούμα
# 91                 1
# 138    πότσου      1   ποτσουνούμενε       φορτώνω    ποτσουνούμα
# 147                1
#
#     pas_orist_aor pas_ypot_aor    Columna1 paradigm
# 30      αποτσούμα  αποστσουθού  αποστσουτέ       Α2
# 91                                               Α2
# 138    εποστσούμα                 ποτσουτέ       Α2
# 147                                              Α2

# %%
# A3
ending = 'ούκ̇ου'
paradigm = 'Α3'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#        tsakonian              greek ypot_enest   orist_aor ypot_aor  \
# 2       αβούκ̇ου             λαβώνω   αβούκ̇ου      αβούκα     αβού
# 19    ανεμούκ̇ου              πετάω               ανεμούκα
# 29    αποσούκ̇ου  πηγαίνω, μεταφέρω               αποσούκα   αποσού
# 35     απρούκ̇ου             απλώνω                απρούκα    απρού
# 64     γκιούκ̇ου              ντύνω               εγκιούκα    γκιου
# 100  κ̇οντούκ̇ου             κρατάω             εκ̇οντούκα  κ̇οντού
# 103    μακούκ̇ου           μαλακώνω               εμακούκα
# 127     ξηούκ̇ου             ξηλώνω                εξηούκα
# 128    οργούκ̇ου             οργώνω                οργούκα    οργού
# 145  σκαρμούκ̇ου  ξαφνιάζω, τρομάζω             εσκαρμούκα
# 168   χαμεούκ̇ου           χαμηλώνω              εχαμεούκα
#
#        metochi prost_aor source        passive passive_greek pas_ypot_enest  \
# 2       αβουτέ      άβου      1
# 19                            1
# 29    αποσουτέ                1
# 35     απρουτέ                1
# 64     γκιουτέ                1  γκιουκ̇ούμενε      ντύνομαι
# 100  κ̇οντουτέ                1
# 103                           1
# 127                           1
# 128    οργουτέ                1
# 145                           1
# 168                           1
#
#     pas_orist_aor pas_ypot_aor Columna1 paradigm
# 2                                             Α3
# 19                                            Α3
# 29                                            Α3
# 35                                            Α3
# 64       εγκιούμα     γκιουθού  γκιουτέ       Α3
# 100                                           Α3
# 103                                           Α3
# 127                                           Α3
# 128                                           Α3
# 145                                           Α3
# 168                                           Α3

# %%
# A4
ending = ('ίχου', 'ίντου', 'ύντου', 'άντου')
paradigm = 'Α4`'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#        tsakonian                       greek ypot_enest  orist_aor   ypot_aor  \
# 1      αβζ̌ύντου  υποφέρω από δίψα, ουρλιάζω                 αβζύα
# 9         ακίχου                     αλατίζω                  ακία
# 10   ακ̇ουγγίχου                     ακουμπώ             ακ̇ουγγία
# 20      ανοίντου                      ανοίγω   ανοίντου      ανοία   ανοίτσου
# 22      αντζίχου                      εγγίζω   αντζίχου     αντζία    αντίξου
# 48     αυγακίχου                      αυξάνω  αυγακίχου    αυγακία  αυγακίσου
# 73     δρανίντου               τρέχω γρήγορα               εδρανία
# 81       θυνίχου                      θυμίζω                εθυνία   θυνίτσου
# 99     κ̇ολλίχου                       κολλώ              εκ̇ολλία
# 121   ντιζικίχου             πειράζω, ενοχλώ
# 125      ξερίχου                ρίχνω, πετάω                εξερία
# 152    τραβίντου                      τραβάω  τραβίντου    ετραβία  τραβίτσου
# 155   τσιταίντου                       πέφτω                ετσιτά
# 166    φωνιάντου                      φωνάζω  φωνιάντου     εφωνιά  φωνιάτσου
#
#       metochi prost_aor source        passive passive_greek pas_ypot_enest  \
# 1                            1
# 9                            1
# 10                           1
# 20    ανοιτ̇έ   άνοιτσε      1   ανοιντούμενε     ανοίγομαι     ανοιντούμα
# 22                           2
# 48                           2
# 73                           1
# 81    θυνιτ̇έ                1      θυμούμενε       θυμάμαι
# 99                           1
# 121                          1
# 125                          1
# 152                          1  τραβιντούμενε     τραβιέμαι    τραβιντούμα
# 155                          1
# 166  φωνιατ̇έ                1  φωνιαντούμενε     φωνάζομαι    φωνιαντούμα
#
#     pas_orist_aor pas_ypot_aor  Columna1 paradigm
# 1                                             Α4`
# 9                                             Α4`
# 10                                            Α4`
# 20         ανοίμα     ανοιτ̇ού   ανοιτ̇έ      Α4`
# 22                                            Α4`
# 48                                            Α4`
# 73                                            Α4`
# 81        εθυνήμα      θυνηθού                Α4`
# 99                                            Α4`
# 121                                           Α4`
# 125                                           Α4`
# 152      ετραβίμα    τραβιτ̇ού  τραβιτ̇έ      Α4`
# 155                                           Α4`
# 166      εφωνιάμα    φωνιατ̇ού  φωνιατ̇έ      Α4`

# %%
# A5
ending = 'ζου'
paradigm = 'Α5'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#        tsakonian                              greek   ypot_enest   orist_aor  \
# 8      ακεικάζου             συμπεραίνω, παρομοιάζω    ακεικάζου      ακεικά
# 11       ακρύζου                      αρτύω, αρτύνω      ακρύζου       αρκύα
# 13   αλικογκίζου                εμποδίζω, καθυστερώ                αλικογκία
# 18   ανανοιρίζου                         αναγνωρίζω  ανανοιρίζου   ανανοιρία
# 21      αντζάζου  ακουμοώ την πληγή και την ερεθίζω     αντζάζου       αντζά
# 26     απογιάζου           ξεγελώ την πείνα με κάτι                   απογιά
# 31    αποφασίζου                          αποφασίζω                 αποφασία
# 32   αποχουρίζου                αποχωρίζω, ξεχωρίζω
# 36     αραδιάζου     αραδιάζω, τοποθετώ καρα σειράν    αραδιάζου      αραδιά
# 39    αρβωνιάζου                        αρραβωνιάζω   αρβωνιάζου  αρβωνιάσου
# 43     αρχινίζου                             αρχίζω    αρχινίζου     αρχινία
# 51      αφορίζου                            αφορίζω     αφορίζου      αφορία
# 56     βασανίζου                  βασανίζω, τυραννώ            -   εβασαν̇ία
# 59    βουκ̇ιάζου                     βουτάω, αρπάζω                 εβουκ̇ιά
# 85     καρδιάζου                             κρυώνω                  εκαρδιά
# 102      κ̇ρύζου                              πλύνω                   εκ̇ρύα
# 119    νιουρίζου                            γνωρίζω    νιουρίζου    ενιουρία
# 124      ξεκάζου                            κοιτάζω
# 173     ψαχνίζου                           στεγνώνω                  εψαχνία
#
#         ypot_aor      metochi prost_aor source           passive  \
# 8      ακεικάσου    ακεικαστέ  ακείκασε   1, 2    ακισταινούμενε
# 11       αρκύσου      αρκυστέ                2
# 13                                           1
# 18   ανανοιρίσου  ανανοιριστέ                2  ανανοιρισκούμενε
# 21      αντζάζου                             1
# 26                                           1
# 31                                           2
# 32                                           2
# 36     αραδιάσου    αραδιαστέ                2
# 39    αρβωνιάσου   αρβωνιαστέ                2   αρβωνιασκούμενε
# 43     αρχινίσου    αρχινιστέ  αρχίνισε      2
# 51      αφορίσου     αφοριστέ                2
# 56     βασανίσου      βανιστέ                2    βασανισκούμενε
# 59                                           1
# 85                                           1
# 102      κ̇ρύσου                             1
# 119    νιουρίσου    νιουριστέ                1    νιουρισκούμενε
# 124                                          1
# 173                                          1
#
#       passive_greek  pas_ypot_enest pas_orist_aor  pas_ypot_aor     Columna1  \
# 8        κουράζομαι                      ακιστάμα
# 11
# 13
# 18    αναγνωρίζομαι  ανανοιρισκούμα   ανανοιρίσμα  ανανοιριστού  ανανοιριστέ
# 21
# 26
# 31
# 32
# 36
# 39   αρραβωνιάζομαι   αρβωνιασκούμα    αρβωνιάσμα   αρβωνιαστού   αρβωνιαστέ
# 43
# 51
# 56      τυραννιέμαι               -    εωασανίσμα    βασανιστού      βανιστέ
# 59
# 85
# 102
# 119      γνωρίζομαι    νιουρισκούμα    ενιουρίσμα    νιουριστού    νιουριστέ
# 124
# 173
#
#     paradigm
# 8         Α5
# 11        Α5
# 13        Α5
# 18        Α5
# 21        Α5
# 26        Α5
# 31        Α5
# 32        Α5
# 36        Α5
# 39        Α5
# 43        Α5
# 51        Α5
# 56        Α5
# 59        Α5
# 85        Α5
# 102       Α5
# 119       Α5
# 124       Α5
# 173       Α5

# %%
# A6
ending = 'φου'
paradigm = 'Α6'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#      tsakonian             greek ypot_enest  orist_aor   ypot_aor    metochi  \
# 65   γκριούφου             κρύβω             εγκριούβα  γκριούψου  γκριουφτέ
# 66      γράφου             γράφω     γράφου     εγράβα      γράψω     γραφτέ
# 97     κιούφου          κοιμάμαι    κιούφου    εκιούβα    κιούψου    κιουφτέ
# 120      νίφου  πλένω το πρόσωπο                 ενίβα
# 123      ξάφου     χτυπώ ξαφνικά                 εξάβα
# 133      πάφου     παύω,σταματάω                 επαύα
# 156    τσ̌ίφου             τρίβω               ετσ̌ίβα
#
#     prost_aor source        passive passive_greek pas_ypot_enest  \
# 65                 1  γκριουφούμενε    γκριουφτού
# 66                 1     γραφούμενε      γράφομαι       γραφούμα
# 97                 1
# 120                1
# 123                1
# 133                1
# 156                1
#
#     pas_orist_aor pas_ypot_aor   Columna1 paradigm
# 65      εγκριούμα   γκριουφτού  γκριουφτέ       Α6
# 66        εγράμμα      γραφτού     γραφτέ       Α6
# 97                                              Α6
# 120                                             Α6
# 123                                             Α6
# 133                                             Α6
# 156                                             Α6

# %%
# A7
ending = 'έγγου'
paradigm = 'Α7'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#          tsakonian                          greek    ypot_enest     orist_aor  \
# 15     αλλαργέγγου       απομακρύνομαι, αλλαργεύω   αλλαργέγγου     αλλαργεύα
# 61        γαλέγγου  ρίχνω τον καρπό πριν ωριμάσει                     εγαλεύα
# 72       δουλέγγου                        δουλεύω                    εδουλεύα
# 74           έγγου                        πηγαίνω         έγγου         εζάκα
# 112       μπλέγγου                         διώχνω      μπλέγγου       εμπλεύα
# 113       μπλέγγου               μπερδεύω, μπλέκω      μπλέγγου        εμπλέα
# 143       σαλέγγου                       κινούμαι                     εσαλεύα
# 149  στενοχωρέγγου                      στενοχωρώ  στενοχωρέγγω  εστενοχωρεύα
#
#          ypot_aor       metochi  prost_aor source            passive  \
# 15     αλλαργέψου                αλλάργεψε      2
# 61                                              1
# 72        δουλέψω      δουλευτέ                 2
# 74           ζάου          ζατέ                 1
# 112       μπλέψου       μπλευτέ                 1
# 113       μπλέξου       μπλεχτέ                 1
# 143                                             1
# 149  στενοχωρέψου  στενοχωρευτέ                 1  στενοχωρεγγούμενε
#
#      passive_greek   pas_ypot_enest pas_orist_aor   pas_ypot_aor  \
# 15
# 61
# 72
# 74
# 112
# 113
# 143
# 149  στεναχωριέμαι  στενοχωρεγγούμα  εστενοχωρέμα  στενοχωρευτού
#
#          Columna1 paradigm
# 15                      Α7
# 61                      Α7
# 72                      Α7
# 74                      Α7
# 112                     Α7
# 113                     Α7
# 143                     Α7
# 149  στενοχωρευτέ       Α7

# %%
# A8
ending = 'ίγγου'
paradigm = 'Α8'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#     tsakonian  greek ypot_enest orist_aor ypot_aor metochi prost_aor source  \
# 141   πρίγγου  πνίγω                επρία  πρίτσου                        1
#
#     passive passive_greek pas_ypot_enest pas_orist_aor pas_ypot_aor Columna1  \
# 141
#
#     paradigm
# 141       Α8

# %%
# A9
ending = 'έχου'
paradigm = 'Α9'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#       tsakonian     greek ypot_enest  orist_aor    ypot_aor metochi prost_aor  \
# 60       βρέχου     βρέχω     βρέχου      εβρέα     βρέτσου  βρετ̇έ
# 76       ερέχου    βρίσκω                 ερέκα       ρέσου  ερεστέ
# 79         έχου       έχω       έχου                   έχου
# 111      μπέχου   σκεπάζω     μπέχου      εμπέα     μπέτσου   μπετέ
# 130    παντέχου  περιμένω
# 140  π̇ουντέχου     σβήνω             επ̇ουντέα  πουντέτσου
#
#     source passive passive_greek pas_ypot_enest pas_orist_aor pas_ypot_aor  \
# 60       1
# 76       1
# 79       1
# 111      1
# 130      1
# 140      1
#
#     Columna1 paradigm
# 60                 Α9
# 76                 Α9
# 79                 Α9
# 111                Α9
# 130                Α9
# 140                Α9

# %%
# A10
ending = 'ίου'
paradigm = 'Α10'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#     tsakonian             greek ypot_enest orist_aor  ypot_aor metochi  \
# 4     αγανίου  παθαίνω οξείδωση               αγανία
# 7    ακαλ̣ίου              κυλώ  ακαλ̣ήνου  ακαλ̣ίκα  ακαλ̣ίου
# 71       δίου              δίνω      δίνου    εδούκα       δου   δουτέ
# 87     κασίου          κοιμάμαι
# 89    κ̇ατίου          τοποθετώ             εκ̇ατίκα
# 118      νίου             ακούω      νίνου    ενιάκα     νιάου   νιατέ
# 122     ντίου             χτυπώ     ντίνου   εντούκα      ντου  ντουτέ
# 132    παρίου           έρχομαι     παρίμα     εκάνα     μόλου   φερτέ
# 136     ποίου              κάνω     ποίνου    εμπήκα     ποίου  μποιτέ
# 144   σαπρίου            σαπίζω              εσαπρία
# 164    φταίου             φταίω              εφταίκα
#
#     prost_aor source passive passive_greek pas_ypot_enest pas_orist_aor  \
# 4                  1
# 7                  1
# 71                 1
# 87                 1
# 89                 1
# 118                1
# 122                1
# 132                1
# 136                1
# 144                1
# 164                1
#
#     pas_ypot_aor Columna1 paradigm
# 4                              Α10
# 7                              Α10
# 71                             Α10
# 87                             Α10
# 89                             Α10
# 118                            Α10
# 122                            Α10
# 132                            Α10
# 136                            Α10
# 144                            Α10
# 164                            Α10

# %%
# A11
ending = 'αίσου'
paradigm = 'Α11'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#    tsakonian greek ypot_enest orist_aor ypot_aor metochi prost_aor source  \
# 67    δαίσου  καίω     δαίσου     εδάκα     δάου                        1
#
#    passive passive_greek pas_ypot_enest pas_orist_aor pas_ypot_aor Columna1  \
# 67
#
#    paradigm
# 67      Α11

# %%
# A12
ending = 'ρίκ̇ου'
paradigm = 'Α12'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#        tsakonian      greek ypot_enest   orist_aor ypot_aor metochi prost_aor  \
# 41       αρίκ̇ου     παίρνω                   άγκα     άρου   παρτέ
# 77       ερίκ̇ου     βρίσκω          -       ερέκα   ερέσου  ερεστέ     έρεσε
# 84  καραφερίκ̇ου  καταφέρνω             εκατανέγκα
#
#    source      passive passive_greek pas_ypot_enest pas_orist_aor  \
# 41      1
# 77      2  ερικ̇ούμενε     βρίσκομαι              -        ερέσμα
# 84      1
#
#    pas_ypot_aor Columna1 paradigm
# 41                            Α12
# 77      ερεστού               Α12
# 84                            Α12

# %%
# A13
ending = 'ρου'
paradigm = 'Α13'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#    tsakonian         greek ypot_enest orist_aor ypot_aor metochi prost_aor  \
# 62    γείρου     επιστρέφω              εγείρκα
# 69     δέρου  δέρνω, χτυπώ               εδάρκα
#
#    source passive passive_greek pas_ypot_enest pas_orist_aor pas_ypot_aor  \
# 62      1
# 69      1
#
#    Columna1 paradigm
# 62               Α13
# 69               Α13

# %%
# A14
ending = 'άσσου'
paradigm = 'Α14'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#     tsakonian    greek ypot_enest orist_aor ypot_aor metochi prost_aor source  \
# 38    αράσσου   αράσσω    αράσσου       αρά  αράτσου                        2
# 46      άσσου   αλλάζω      άσσου      α/εά    άτσου    ατ̇έ      άτσε      1
# 137  ποτάσσου  φτουράω                εποτά                                 1
#
#     passive passive_greek pas_ypot_enest pas_orist_aor pas_ypot_aor Columna1  \
# 38
# 46
# 137
#
#     paradigm
# 38       Α14
# 46       Α14
# 137      Α14

# %% [markdown]
# # Β paradigms

# %% [markdown]
# Verbs ending in `-ού`

# %%
# Β1
ending = 'ού'
aoristos_ending = 'άκα'
paradigm = 'Β1'

add = True
mask = (df['tsakonian'].str.endswith(ending) & 
        df['orist_aor'].str.endswith(aoristos_ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#     tsakonian          greek ypot_enest orist_aor ypot_aor   metochi  \
# 37     αραμού  μένω, κατοικώ   αραμήνου   αραμάκα  αραμάου   αραματέ
# 58        βού          κλαίω     βούνου     εβάκα   βάτσου
# 63       γεού          γελάω   γελ̣ήνου    εγιάκα    γιάου
# 94      κιμού           τιμώ              εκιμάκα
# 106     μοζού          πονάω    μοζήνου   εμοζάκα   μοζάου  μοζαΐχου
# 129      ορού          βλέπω     ορήνου     οράκα    οράου     ορατέ
# 135     περού          περνώ    περήνου   επεράκα   περάου    περατέ
# 161    φουσού          φυσάω   φουσήνου  εφουσάκα  φουσάου
# 170      χαού          χαλάω   χαλ̣ήνου     εχάκα     χάου      χατέ
#
#     prost_aor source   passive passive_greek pas_ypot_enest pas_orist_aor  \
# 37      αράμα      1
# 58                 1
# 63                 1
# 94                 1
# 106                1
# 129                1  ορούμενε      φαίνομαι       ορινούμα         οράμα
# 135                1
# 161                1
# 170                1
#
#     pas_ypot_aor Columna1 paradigm
# 37                              Β1
# 58                              Β1
# 63                              Β1
# 94                              Β1
# 106                             Β1
# 129       οραθού    ορατέ       Β1
# 135                             Β1
# 161                             Β1
# 170                             Β1

# %%
# Β2
ending = 'ού'
aoristos_ending = 'ήκα'
paradigm = 'Β2'

add = True
mask = (df['tsakonian'].str.endswith(ending) & 
        df['orist_aor'].str.endswith(aoristos_ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#      tsakonian            greek   ypot_enest    orist_aor    ypot_aor  \
# 5      αγκατού           φράσσω                   αγατήκα
# 12   αλησμονού  λησμονώ, ξεχνάω  αλησμονήνου   αλησμονήκα  αλησμονήου
# 16      αμογού          ομολογώ                   αμογήκα
# 42        αρού           αρμέγω       αρήνου        αρήκα       αρήου
# 44        ασού          σουρώνω                     ασήκα
# 45     ασπηδού            πηδάω    ασπηδήνου     ασπηδήκα      ασπήου
# 53       αωνού          αλωνίζω     αων̇ήνου      αων̇ήκα     αων̇ήου
# 57       βογού           ευλογώ                    βογήκα
# 80     ζυρογού       βρωμοκοπάω                 εζυρογήκα
# 101    κουβαού          κουβαλώ               εκουβαλ̣ήκα
# 104    μετσ̌ού            μετρώ                 εμετσ̌ήκα
# 116      νικού             νικώ                  ενιτζήκα     νιτζήου
# 117       νιού            μηλάω     νιλ̣ήνου     ενιλ̣ήκα     νιλ̣ήου
# 142      ρωτού            ρωτάω      ρωτήνου      ερωτήκα      ρωτήου
# 158    τσ̌υγού            τρυγώ                εστσ̌υγήκα
# 172      ψαφού            ψάχνω      ψαφήνου      εψαφήκα      ψαφήου
#
#         metochi  prost_aor source           passive        passive_greek  \
# 5                               1
# 12   αλησμονητέ  αλησμόν̇η      2  αλησμονικ̇ούμενε  λησμόμαι, ξεχνιέμαι
# 16                              1
# 42        αρητέ        αρή      1
# 44                              1
# 45                  ασπηδή      2
# 53      αωνιστέ      αων̇ή      2      αωνικ̇ούμενε           αλωνίζομαι
# 57                              1
# 80                              1
# 101                             1
# 104                             1
# 116                             2
# 117     νιλ̣ητέ                 1
# 142      ρωτητέ                 1      ρωτηκ̇ούμενε             ρωτιέμαι
# 158                             1
# 172      ψαφητέ                 1
#
#      pas_ypot_enest pas_orist_aor pas_ypot_aor    Columna1 paradigm
# 5                                                                Β2
# 12   αλησμονικ̇ούμα    αλησμονήμα  αλησμονηθού  αλησμονητέ       Β2
# 16                                                               Β2
# 42                                                               Β2
# 44                                                               Β2
# 45                                                               Β2
# 53       αωνικ̇ούμα       αων̇ήμα     αων̇ηθού     αωνιστέ       Β2
# 57                                                               Β2
# 80                                                               Β2
# 101                                                              Β2
# 104                                                              Β2
# 116                                                              Β2
# 117                                                              Β2
# 142      ρωτηκ̇ούμα       ερωτήμα      ρωτηθού      ρωτητέ       Β2
# 158                                                              Β2
# 172                                                              Β2

# %%
# Β3
ending = 'ού'
aoristos_ending = 'έκα'
paradigm = 'Β3'

add = True
mask = (df['tsakonian'].str.endswith(ending) & 
        df['orist_aor'].str.endswith(aoristos_ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#       tsakonian                     greek ypot_enest     orist_aor ypot_aor  \
# 23          αού                       λέω     αλήνου         επέκα    αλήου
# 95      κιμωρού                    τιμωρώ                εκιμωρέκα
# 114      μπορού                     μπορώ                 εμπορέκα  μπορέου
# 131  παραθαρρού  χαλαρώνω την προσοχή μου             επαραθαρρέκα
# 160       φορού                     φοράω    φορήνου       εφορέκα   φορέου
#
#      metochi prost_aor source passive passive_greek pas_ypot_enest  \
# 23      πετέ                1
# 95                          1
# 114                         1
# 131                         1
# 160  φορεστέ                1
#
#     pas_orist_aor pas_ypot_aor Columna1 paradigm
# 23                                            Β3
# 95                                            Β3
# 114                                           Β3
# 131                                           Β3
# 160                                           Β3

# %% [markdown]
# # Γ paradigms: passive voices

# %%
# Γ
ending = 'ε'
paradigm = 'Γ'

add = True
mask = (df['tsakonian'].str.endswith(ending))

if add:
    df.loc[mask, 'paradigm'] = paradigm
display(df[mask])
# Out:
#          tsakonian                     greek   ypot_enest orist_aor  \
# 3     αβουκ̇ούμενε                 λαβώνομαι   αβουκ̇ούμα    αβούμα
# 14    αλ̣ικ̇ούμενε                   λέγομαι   αλ̣ικ̇ούμα     επέμα
# 17   αναλλεγούμενε  αναλογίζομαι, στοχάζομαι  αναλλεγούμα   αναλέμα
# 40     αρεσκούμενε                    αρέσει
# 78     ερικ̇ούμενε                 βρίσκομαι            -    ερέσια
# 86        κασημένε                   κάθομαι       κασήμα  εκατσάκα
# 148    σουσκούμενε                  τελειώνω                εσούσμα
# 163    φταινούμενε                   ψήνομαι                 εφτάμα
# 167  φωνιαντούμενε                 φωνάζομαι  φωνιαντούμα  εφωνιάμα
#
#       ypot_aor      metochi prost_aor source passive passive_greek  \
# 3      αβουθού                 αβουτέ      2
# 14      αλ̣ήμα  πετέ/αλ̣ητέ                2
# 17   αναλετ̇ού                             2
# 40                                         2
# 78      ρεστού                             1
# 86     κατσάου      κατσατέ                1
# 148    σουστού       σουστέ                1
# 163     φταθού        φτατέ                1
# 167  φωνιατ̇ού                             1
#
#     pas_ypot_enest pas_orist_aor pas_ypot_aor Columna1 paradigm
# 3                                                             Γ
# 14                                                            Γ
# 17                                                            Γ
# 40                                                            Γ
# 78                                                            Γ
# 86                                                            Γ
# 148                                                           Γ
# 163                                                           Γ
# 167                                                           Γ

# %% [markdown]
# # Unorganized verbs

# %%
# Extract verbs where the paradigm is empty
df[df['paradigm'].isnull()]
# Out:
#        tsakonian                  greek  ypot_enest  orist_aor     ypot_aor  \
# 24        απλέου          πλέω, κολυμβώ      απλέου     απλέκα       απλέου
# 27    αποδενάχου  αποδεικνύω, αποδείχνω  αποδενάχου    αποδενά  αποδενάτσου
# 28         αποού                 στέλνω               απολ̣ύκα
# 33   αποχρεύκ̇ου              υποχρεώνω
# 49       αυράχου                 αρπάζω     αυράχου       αυρά     αυράτσου
# 52      αφρίνδου                 αφρίζω           -      αφρία     αφρίτσου
# 75           ένι                  είμαι         ένι        έμα          ένι
# 82    κ̇ακ̇ούχου            χώνω, έχωσα              εκ̇ακ̇ούα
# 83         κάμου       καματεύω, σπέρνω                εκαμεκα       καμέου
# 92        κεινού                 πεινάω               εκείνακα      κεινάου
# 109      μπαΐχου        εμπάζω, ανεβάζω     μπαΐχου     εμπαΐα      μπαΐσου
# 115        νέμου                  βοσκώ       νέμου    ενεμάκα       νεμάου
# 134     πενάκ̇ου                πεθαίνω                επενάκα      πεθάνου
# 139          που                 πουλάω   πουλ̣ήνου  επουλ̣ήκα     πουλ̣ήου
# 146       σκωρού                συγχωρώ              εσκουγκία
# 151      τ̇αΐχου                 σηκώνω     τ̇αΐχου     ετ̇αΐα      τ̇αΐσου
# 154      τσ̌άχου                  τρέχω     τσ̌αχου  ετσ̌αχήκα   τσ̌αχίτσου
# 157        τσ̌ου                   τρώω    τσ̌ούνου     εφαήκα         φάου
# 159     φοζαΐχου                 φοβίζω                εφοζαΐα
# 165         φύου                  φεύγω       φύνου     εφύγκα       φύτσου
#
#      metochi prost_aor source      passive passive_greek pas_ypot_enest  \
# 24                άπλε      2
# 27                          2
# 28                          1
# 33                          2
# 49   αυρατ̇έ   αυράτσε      2  αυραχούμενε     αρπάζομαι      αυραχούμα
# 52                          2
# 75                          1
# 82                          1
# 83                          1
# 92   κεινατέ                1
# 109   μπαϊτέ    μπάϊσε      2  μπαϊχούμενε    ανεβάζομαι
# 115   νεματέ                1
# 134   πενατέ                1
# 139                         1
# 146                         1
# 151  τ̇αΐστέ                1
# 154                         1
# 157    φαητέ                1
# 159                         1
# 165                         1
#
#     pas_orist_aor pas_ypot_aor Columna1 paradigm
# 24                                           NaN
# 27                                           NaN
# 28                                           NaN
# 33                                           NaN
# 49         αυράμα     αυρατ̇ού  αυρατ̇έ      NaN
# 52                                           NaN
# 75                                           NaN
# 82                                           NaN
# 83                                           NaN
# 92                                           NaN
# 109      μπαϊτ̇ού                μπαϊτέ      NaN
# 115                                          NaN
# 134                                          NaN
# 139                                          NaN
# 146                                          NaN
# 151                                          NaN
# 154                                          NaN
# 157                                          NaN
# 159                                          NaN
# 165                                          NaN
